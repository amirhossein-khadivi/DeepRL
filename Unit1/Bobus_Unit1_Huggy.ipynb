# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2385, done.
# remote: Counting objects: 100% (2385/2385), done.
# remote: Compressing objects: 100% (1904/1904), done.
# remote: Total 2385 (delta 904), reused 1207 (delta 462), pack-reused 0
# Receiving objects: 100% (2385/2385), 97.66 MiB | 35.29 MiB/s, done.
# Resolving deltas: 100% (904/904), done.
# Updating files: 100% (2215/2215), done.

# %%
# %cd ml-agents
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents
# Out:
# /content/ml-agents
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 84.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 82.3 MB/s eta 0:00:00
# ...
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875633 sha256=2dabec934be7409cb28c62e172e4a3e0b304cc59fb222b1c3704c99b2d1eb1d2
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# Successfully built pettingzoo
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
# ...

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget "https://github.com/huggingface/Huggy/raw/main/Huggy.zip" -O ./trained-envs-executables/linux/Huggy.zip
# Out:
# --2024-08-08 12:31:27--  https://github.com/huggingface/Huggy/raw/main/Huggy.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip [following]
# --2024-08-08 12:31:27--  https://media.githubusercontent.com/media/huggingface/Huggy/main/Huggy.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/zip]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M  --.-KB/s    in 0.1s
#
# ...

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !chmod -R 755 ./trained-envs-executables/linux/Huggy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !which mlagents-learn

# %%
# !pip show mlagents
# Out:
# WARNING: Package(s) not found: mlagents

# %%
# !pip install mlagents
# Out:
# ...
#   Using cached cattrs-1.5.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !export PATH=$PATH:/content/ml-agents
/content/ml-agents/config/ppo/Huggy.yaml

# %%
# !mlagents-learn /content/ml-agents/config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:749: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:431.)
#   _C._set_default_tensor_type(t)
# 2024-08-08 12:53:35.248213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-08 12:53:35.267926: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-08 12:53:35.273779: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="/content/results/Huggy" --repo-id="khadivi-ah/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-1399999.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Upload 25 LFS files:   0% 0/25 [00:00<?, ?it/s]
#
# Huggy-1199930.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1199930.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-1599626.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Huggy-1399999.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# Huggy-1199930.pt:  34% 4.62M/13.5M [00:00<00:00, 46.2MB/s]
#
# Huggy-1399999.pt:  39% 5.32M/13.5M [00:00<00:00, 36.1MB/s]
#
#
#
# Huggy-1399999.pt:  66% 8.95M/13.5M [00:00<00:00, 22.8MB/s]
#
#
# Huggy-1199930.onnx: 100% 2.27M/2.27M [00:00<00:00, 4.78MB/s]
# Huggy-1399999.onnx: 100% 2.27M/2.27M [00:00<00:00, 4.14MB/s]
# Huggy-1599626.onnx: 100% 2.27M/2.27M [00:00<00:00, 3.86MB/s]
#
# ...
