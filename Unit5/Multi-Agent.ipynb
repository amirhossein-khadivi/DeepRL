# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2393, done.
# remote: Counting objects: 100% (2393/2393), done.
# remote: Compressing objects: 100% (1923/1923), done.
# remote: Total 2393 (delta 901), reused 1267 (delta 451), pack-reused 0 (from 0)
# Receiving objects: 100% (2393/2393), 97.66 MiB | 14.27 MiB/s, done.
# Resolving deltas: 100% (901/901), done.
# Updating files: 100% (2222/2222), done.

# %%
# !pip install -e /content/ml-agents/ml-agents-envs
# !pip install -e /content/ml-agents/ml-agents
# Out:
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 40.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 96.0 MB/s eta 0:00:00
# ...
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875633 sha256=410351e8164af3c68eb0a1a1e91fc71ea4d74f045846b9eb738064eee6089748
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# Successfully built pettingzoo
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
# ...

# %%
# !pip install mlagents
# Out:
# ...
#   Using cached cattrs-1.5.0-py3-none-any.whl.metadata (16 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.3/171.3 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 96.8 MB/s eta 0:00:00
# Using cached cattrs-1.5.0-py3-none-any.whl (19 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: onnx
#     Found existing installation: onnx 1.15.0
#     Uninstalling onnx-1.15.0:
# ...

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !wget "https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip" -O ./training-envs-executables/linux/SnowballTarget.zip
# Out:
# --2024-08-27 13:37:58--  https://github.com/huggingface/Snowball-Target/raw/main/SnowballTarget.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip [following]
# --2024-08-27 13:37:58--  https://media.githubusercontent.com/media/huggingface/Snowball-Target/main/SnowballTarget.zip
# Resolving media.githubusercontent.com (media.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to media.githubusercontent.com (media.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35134213 (34M) [application/zip]
# Saving to: ‘./training-envs-executables/linux/SnowballTarget.zip’
#
# ./training-envs-exe 100%[===================>]  33.51M  --.-KB/s    in 0.1s
#
# ...

# %%
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/SnowballTarget.zip
# Out:
# Archive:  ./training-envs-executables/linux/SnowballTarget.zip
#    creating: ./training-envs-executables/linux/SnowballTarget/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget.x86_64
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/Plugins/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_BurstDebugInformation_DoNotShip/Data/Plugins/lib_burst_generated.txt
#    creating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/app.info
#   inflating: ./training-envs-executables/linux/SnowballTarget/SnowballTarget_Data/boot.config
# ...

# %%
# !chmod -R 755 ./training-envs-executables/linux/SnowballTarget

# %%
# !mlagents-learn /content/ml-agents/config/ppo/SnowballTarget.yaml --env=/content/training-envs-executables/linux/SnowballTarget/SnowballTarget.x86_64 --run-id="SnowballTarget" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# 2024-08-27 13:41:03.224774: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-27 13:41:03.256231: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-27 13:41:03.266895: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !mlagents-push-to-hf --run-id 'SnowballTarget' --local-dir '/content/results/SnowballTarget' --repo-id 'khadivi-ah/ppo-SnowballTarget' --commit-message 'First Push'
# Out:
# [INFO] This function will create a model card and upload your SnowballTarget into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SnowballTarget to the Hugging Face Hub
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
# SnowballTarget-149984.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
# SnowballTarget-199984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
# SnowballTarget-149984.pt:   0% 0.00/3.85M [00:00<?, ?B/s]
#
#
#
#
# Upload 13 LFS files:   0% 0/13 [00:00<?, ?it/s]
#
#
#
# SnowballTarget.onnx:   0% 0.00/651k [00:00<?, ?B/s]
#
#
# SnowballTarget-199984.pt:  21% 803k/3.85M [00:00<00:00, 7.97MB/s]
#
#
# SnowballTarget-199984.pt:  42% 1.61M/3.85M [00:00<00:00, 6.85MB/s]
#
#
# SnowballTarget-199984.pt:  60% 2.31M/3.85M [00:00<00:00, 5.54MB/s]
#
#
# SnowballTarget.onnx: 100% 651k/651k [00:01<00:00, 518kB/s]
# SnowballTarget.onnx: 100% 651k/651k [00:01<00:00, 491kB/s]
# ...

# %% [markdown]
# # Pyramid

# %%
# !wget "https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip" -O ./training-envs-executables/linux/Pyramids.zip
# Out:
# --2024-08-27 13:59:44--  https://huggingface.co/spaces/unity/ML-Agents-Pyramids/resolve/main/Pyramids.zip
# Resolving huggingface.co (huggingface.co)... 13.33.28.87, 13.33.28.54, 13.33.28.94, ...
# Connecting to huggingface.co (huggingface.co)|13.33.28.87|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip -d ./training-envs-executables/linux/ ./training-envs-executables/linux/Pyramids.zip
# Out:
# Archive:  ./training-envs-executables/linux/Pyramids.zip
#    creating: ./training-envs-executables/linux/Pyramids/
#   inflating: ./training-envs-executables/linux/Pyramids/UnityPlayer.so
#   inflating: ./training-envs-executables/linux/Pyramids/Pyramids
#    creating: ./training-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/
#    creating: ./training-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/
#    creating: ./training-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/Plugins/
#   inflating: ./training-envs-executables/linux/Pyramids/Pyramids_BurstDebugInformation_DoNotShip/Data/Plugins/lib_burst_generated.txt
#    creating: ./training-envs-executables/linux/Pyramids/Pyramids_Data/
#   inflating: ./training-envs-executables/linux/Pyramids/Pyramids_Data/resources.assets
#   inflating: ./training-envs-executables/linux/Pyramids/Pyramids_Data/app.info
# ...

# %%
# !chmod -R 755 ./training-envs-executables/linux/Pyramids/Pyramids

# %%
# !mlagents-learn /content/ml-agents/config/ppo/PyramidsRND.yaml --env=/content/training-envs-executables/linux/Pyramids/Pyramids --run-id="Pyramids Training" --no-graphics
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py:955: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:432.)
#   _C._set_default_tensor_type(t)
# 2024-08-27 14:07:30.870000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-27 14:07:30.890460: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-27 14:07:30.896387: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !mlagents-push-to-hf --run-id 'Pyramids Training' --local-dir '/content/results/Pyramids Training' --repo-id 'khadivi-ah/ppo-PyramidsRND' --commit-message 'Second Push'
# Out:
# [INFO] This function will create a model card and upload your Pyramids Training into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo Pyramids Training to the Hugging Face Hub
# Pyramids-499950.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
# Pyramids-1000066.pt:   0% 0.00/8.66M [00:00<?, ?B/s]
#
# Pyramids.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
#
#
# Pyramids.onnx:   0% 0.00/1.42M [00:00<?, ?B/s]
#
#
#
# Upload 9 LFS files:   0% 0/9 [00:00<?, ?it/s]
#
#
#
#
# Pyramids-499950.pt:   0% 0.00/8.66M [00:00<?, ?B/s]
# Pyramids-1000066.pt:  29% 2.52M/8.66M [00:00<00:00, 25.2MB/s]
#
#
#
#
# Pyramids-499950.pt:  20% 1.72M/8.66M [00:00<00:00, 8.54MB/s]
#
#
#
#
# Pyramids-499950.pt:  30% 2.59M/8.66M [00:00<00:02, 2.33MB/s]
# Pyramids-1000066.pt:  58% 5.05M/8.66M [00:01<00:00, 4.29MB/s]
#
#
#
#
# Pyramids-499950.pt:  59% 5.08M/8.66M [00:01<00:00, 5.23MB/s]
# Pyramids-1000066.pt:  76% 6.54M/8.66M [00:01<00:00, 5.17MB/s]
#
#
#
#
# ...
