# %%
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2395, done.
# remote: Counting objects: 100% (2395/2395), done.
# remote: Compressing objects: 100% (1927/1927), done.
# remote: Total 2395 (delta 904), reused 1298 (delta 449), pack-reused 0 (from 0)
# Receiving objects: 100% (2395/2395), 97.66 MiB | 14.93 MiB/s, done.
# Resolving deltas: 100% (904/904), done.
# Updating files: 100% (2228/2228), done.

# %%
# !pip install -e /content/ml-agents/ml-agents-envs
# !pip install -e /content/ml-agents/ml-agents
# Out:
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 35.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 66.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 95.2 MB/s eta 0:00:00
# ...
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875633 sha256=fae70f58d09d1f6470fe5baba3e76b362cecb7ac9e2e46b72c33407ae0362ca9
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# Successfully built pettingzoo
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.64.1
#     Uninstalling grpcio-1.64.1:
# ...

# %%
# !pip install mlagents

# %%
# !mkdir ./training-envs-executables
# !mkdir ./training-envs-executables/linux

# %%
# !unzip -d ./training-envs-executables/linux/ /content/SoccerTwos.zip
# Out:
# Archive:  /content/SoccerTwos.zip
#    creating: ./training-envs-executables/linux/SoccerTwos_Data/
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/app.info
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/boot.config
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/globalgamemanagers
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/globalgamemanagers.assets
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/level0
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/level0.resS
#    creating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Assembly-CSharp.dll
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Google.Protobuf.dll
#   inflating: ./training-envs-executables/linux/SoccerTwos_Data/Managed/Grpc.Core.dll
# ...

# %%
# !chmod -R 755 ./training-envs-executables/linux
#!chmod -R 755 /content/training-envs-executables/linux/SoccerTwos.x86_64

# %%
# !mlagents-learn /content/ml-agents/config/poca/SoccerTwos.yaml --env=/content/training-envs-executables/linux/SoccerTwos.x86_64 --run-id="SoccerTwos2" --no-graphics
# Out:
# 2024-09-04 14:17:34.473473: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 14:17:34.493194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 14:17:34.499131: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-04 14:17:34.512942: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !mlagents-push-to-hf --run-id 'SoccerTwos2' --local-dir '/content/results/SoccerTwos2' --repo-id 'khadivi-ah/poca-SoccerTwos' --commit-message 'Push'
# Out:
# [INFO] This function will create a model card and upload your SoccerTwos2 into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo SoccerTwos2 to the Hugging Face Hub
# SoccerTwos-1999008.pt:   0% 0.00/28.4M [00:00<?, ?B/s]
# Upload 13 LFS files:   0% 0/13 [00:00<?, ?it/s]
#
#
# SoccerTwos-1499396.pt:   0% 0.00/28.4M [00:00<?, ?B/s]
#
#
#
# SoccerTwos-1499396.onnx:   0% 0.00/1.77M [00:00<?, ?B/s]
#
# SoccerTwos.onnx:   0% 0.00/1.77M [00:00<?, ?B/s]
#
#
#
#
# SoccerTwos-1999008.onnx:   0% 0.00/1.77M [00:00<?, ?B/s]
#
#
#
# SoccerTwos-1999008.pt:   5% 1.44M/28.4M [00:00<00:02, 12.7MB/s]
#
#
# SoccerTwos-1499396.pt:   5% 1.52M/28.4M [00:00<00:02, 11.5MB/s]
#
# SoccerTwos.onnx:  95% 1.69M/1.77M [00:00<00:00, 10.4MB/s]
#
#
#
#
# SoccerTwos-1999008.onnx:  94% 1.65M/1.77M [00:00<00:00, 9.57MB/s]
#
#
# SoccerTwos-1999008.pt:  10% 2.72M/28.4M [00:01<00:12, 2.08MB/s]
#
#
# ...
